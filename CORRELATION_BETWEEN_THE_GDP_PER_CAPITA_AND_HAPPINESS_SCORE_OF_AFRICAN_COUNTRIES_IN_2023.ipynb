# %% [markdown]
# <a href="https://colab.research.google.com/github/ChiomaO15/Africa-Happiness-Report-2023/blob/main/CORRELATION_BETWEEN_THE_GDP_PER_CAPITA_AND_HAPPINESS_SCORE_OF_AFRICAN_COUNTRIES_IN_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **IMPORTING AFRICA HAPPINESS REPORT 2023 DATA**

# %%
pip install pandas

# %%
import pandas as pd

df = pd.read_csv('Africa Happiness Report 2023.csv')

print(df.to_string())
# Out:
#                 country                        region  happiness_score  gdp_per_capita  social_support  healthy_life_expectancy  freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0               Nigeria            Sub-Saharan Africa            4.981           1.065           1.007                    0.092                         0.448       0.176                      0.013
# 1           Ivory Coast            Sub-Saharan Africa            5.100           1.094           0.584                    0.120                         0.467       0.138                      0.131
# 2                 Gabon            Sub-Saharan Africa            5.100           1.438           1.021                    0.183                         0.346       0.036                      0.102
# 3          South Africa            Sub-Saharan Africa            5.400           1.417           1.428                    0.149                         0.464       0.090                      0.019
# ...

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
print(df.head(10))
# Out:
#                country              region  happiness_score  gdp_per_capita  \
# 0              Nigeria  Sub-Saharan Africa            4.981           1.065
# 1          Ivory Coast  Sub-Saharan Africa            5.100           1.094
# 2                Gabon  Sub-Saharan Africa            5.100           1.438
# 3         South Africa  Sub-Saharan Africa            5.400           1.417
# 4  Congo (Brazzaville)  Sub-Saharan Africa            5.267           0.921
# 5            Mauritius  Sub-Saharan Africa            5.800           1.589
# 6               Guinea  Sub-Saharan Africa            5.072           0.844
# 7             Cameroon  Sub-Saharan Africa            4.973           0.965
# 8           Mozambique  Sub-Saharan Africa            5.200           0.570
# 9         Burkina Faso  Sub-Saharan Africa            4.638           0.768
#
#    social_support  healthy_life_expectancy  freedom_to_make_life_choices  \
# ...

# %%
print(df.tail(10))
# Out:
#              country                        region  happiness_score  \
# 29          Botswana            Sub-Saharan Africa            3.435
# 30  Congo (Kinshasa)            Sub-Saharan Africa            5.200
# 31          Zimbabwe            Sub-Saharan Africa            3.300
# 32      Sierra Leone            Sub-Saharan Africa            3.200
# 33           Morocco  Middle East and North Africa            4.800
# 34           Algeria  Middle East and North Africa            5.400
# 35           Senegal            Sub-Saharan Africa            5.000
# 36             Libya  Middle East and North Africa            5.900
# 37               DRC            Sub-Saharan Africa            3.300
# 38           Lesotho            Sub-Saharan Africa            3.200
#
#     gdp_per_capita  social_support  healthy_life_expectancy  \
# 29           1.471           1.041                    0.087
# 30           0.531           0.784                    0.105
# ...

# %% [markdown]
# ## **CLEANING THE DATA**

# %%
df = pd.read_csv('Africa Happiness Report 2023.csv')

df.fillna(0, inplace = True)

# %%
print(df.to_string())
# Out:
#                 country                        region  happiness_score  gdp_per_capita  social_support  healthy_life_expectancy  freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0               Nigeria            Sub-Saharan Africa            4.981           1.065           1.007                    0.092                         0.448       0.176                      0.013
# 1           Ivory Coast            Sub-Saharan Africa            5.100           1.094           0.584                    0.120                         0.467       0.138                      0.131
# 2                 Gabon            Sub-Saharan Africa            5.100           1.438           1.021                    0.183                         0.346       0.036                      0.102
# 3          South Africa            Sub-Saharan Africa            5.400           1.417           1.428                    0.149                         0.464       0.090                      0.019
# ...

# %% [markdown]
# ## **REMOVING DUPLICATES**

# %%
df = pd.read_csv('Africa Happiness Report 2023.csv')

print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# dtype: bool

# %% [markdown]
# ## **FINDING CORRELATION**

# %%
df.head()
# Out:
#                country              region  happiness_score  gdp_per_capita  \
# 0              Nigeria  Sub-Saharan Africa            4.981           1.065
# 1          Ivory Coast  Sub-Saharan Africa            5.100           1.094
# 2                Gabon  Sub-Saharan Africa            5.100           1.438
# 3         South Africa  Sub-Saharan Africa            5.400           1.417
# 4  Congo (Brazzaville)  Sub-Saharan Africa            5.267           0.921
#
#    social_support  healthy_life_expectancy  freedom_to_make_life_choices  \
# 0           1.007                    0.092                         0.448
# 1           0.584                    0.120                         0.467
# 2           1.021                    0.183                         0.346
# 3           1.428                    0.149                         0.464
# 4           0.665                    0.145                         0.464
#
#    generosity  perceptions_of_corruption
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('Africa Happiness Report 2023.csv')

df.fillna(0, inplace = True)

# %%
print(df.to_string())
# Out:
#                 country                        region  happiness_score  gdp_per_capita  social_support  healthy_life_expectancy  freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0               Nigeria            Sub-Saharan Africa            4.981           1.065           1.007                    0.092                         0.448       0.176                      0.013
# 1           Ivory Coast            Sub-Saharan Africa            5.100           1.094           0.584                    0.120                         0.467       0.138                      0.131
# 2                 Gabon            Sub-Saharan Africa            5.100           1.438           1.021                    0.183                         0.346       0.036                      0.102
# 3          South Africa            Sub-Saharan Africa            5.400           1.417           1.428                    0.149                         0.464       0.090                      0.019
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       39 non-null     object
#  1   region                        39 non-null     object
#  2   happiness_score               39 non-null     float64
#  3   gdp_per_capita                39 non-null     float64
#  4   social_support                39 non-null     float64
#  5   healthy_life_expectancy       39 non-null     float64
#  6   freedom_to_make_life_choices  39 non-null     float64
#  7   generosity                    39 non-null     float64
#  8   perceptions_of_corruption     39 non-null     float64
# dtypes: float64(7), object(2)
# memory usage: 2.9+ KB

# %% [markdown]
# ## **CONVERTING OBJECTS TO A CATEGORY TO GET CORRELATION**

# %%
df = pd.read_csv('/Africa Happiness Report 2023.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       39 non-null     object
#  1   region                        39 non-null     object
#  2   happiness_score               39 non-null     float64
#  3   gdp_per_capita                33 non-null     float64
#  4   social_support                33 non-null     float64
#  5   healthy_life_expectancy       33 non-null     float64
#  6   freedom_to_make_life_choices  33 non-null     float64
#  7   generosity                    33 non-null     float64
#  8   perceptions_of_corruption     33 non-null     float64
# dtypes: float64(7), object(2)
# memory usage: 2.9+ KB

# %%
df['country'] = df['country'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-aba17a33498a> in <cell line: 1>()
# ----> 1 df['country'] = df['country'].astype(float)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
#
# ...

# %%
df['country'].dtypes
# Out:
# dtype('O')

# %%
df['country'] = df['country'].astype('category')

# %%
df['country'].dtypes
# Out:
# CategoricalDtype(categories=['Algeria', 'Benin', 'Botswana', 'Burkina Faso', 'Cameroon',
#                   'Chad', 'Comoros', 'Congo (Brazzaville)', 'Congo (Kinshasa)',
#                   'DRC', 'Egypt', 'Ethiopia', 'Gabon', 'Gambia', 'Ghana',
#                   'Guinea', 'Ivory Coast', 'Kenya', 'Lesotho', 'Liberia',
#                   'Libya', 'Madagascar', 'Malawi', 'Mali', 'Mauritius',
#                   'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria',
#                   'Senegal', 'Sierra Leone', 'South Africa', 'Tanzania',
#                   'Togo', 'Tunisia', 'Uganda', 'Zambia', 'Zimbabwe'],
# , ordered=False)

# %%
df.corr()
# Out:
# <ipython-input-22-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                               happiness_score  gdp_per_capita  social_support  \
# happiness_score                      1.000000        0.266950        0.369992
# gdp_per_capita                       0.266950        1.000000        0.551326
# social_support                       0.369992        0.551326        1.000000
# freedom_to_make_life_choices         0.161439        0.062596        0.216423
# generosity                          -0.062081       -0.596665       -0.178389
# perceptions_of_corruption           -0.141453       -0.130791       -0.348589
#
#                               freedom_to_make_life_choices  generosity  \
# happiness_score                                   0.161439   -0.062081
# ...

# %% [markdown]
# ## **GRAPHICAL REPRESENTATION OF CORRELATION**

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Africa Happiness Report 2023.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/Africa Happiness Report 2023.csv')

df.plot()

plt.show()

# %%
import pandas as pd
df = pd.read_csv('/content/Africa Happiness Report 2023.csv')

# %%
import seaborn as sns
sns.scatterplot(x="gdp_per_capita", y="happiness_score", data=pd.read_csv("/content/Africa Happiness Report 2023.csv"))
# Out:
# <Axes: xlabel='gdp_per_capita', ylabel='happiness_score'>

# %%
sns.lmplot(x="gdp_per_capita", y="happiness_score", hue="region", data=pd.read_csv("/content/Africa Happiness Report 2023.csv"))

# %%
correlation = df["gdp_per_capita"]. corr (df["happiness_score"])
print ("The correlation number between gdp_per_capita and happiness_score: ", correlation)
# Out:
# The correlation number between gdp_per_capita and happiness_score:  0.2669501428033382

# %% [markdown]
# ##   The correlation between Gdp_per_capita and happiness score is 0.266950 which means there is a weak positive relationship between the two variables.
# ##   A weak positive correlation indicates that, although both variables tend to go up in response to one another, the relationship is not very strong.
